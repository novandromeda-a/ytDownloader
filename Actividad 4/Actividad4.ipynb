# %% [markdown]
# ![logo.png](data:image/png;base64,...)
#
#
#
# # **Actividad 4**
#
# *Análisis Exploratorio de Datos en Python*
#
# Iveth Rocio Navarro Lopez
#
#
#
# ---

# %% [markdown]
# **Actividad 4.1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Creación de DATA FRAME dela base de datos y uno adicional para trabajar

url= "https://raw.githubusercontent.com/novandromeda-a/Computational-physics/master/Actividad%201/Base%20de%20datos%20climatol%C3%B3gica.txt"

e=["Fecha","Precip","Evap","Tmax","Tmin"] #Encabezados de las columnas en la 
                                          #base de datos

df_weather = pd.read_csv(url, names=e, encoding='cp1251', sep='\s+', header=None, skiprows=19, skipfooter=1, engine='python')                                          
#Declaración de DATA FRAME

#print(df_weather.head(10)) 
#print(df_weather.tail(10)) 
#df_weather.shape  
#df_weather.info()

df_weather1=df_weather.copy() #Este data frame será con el que trabajemos
df_weather1.head()

str_Nulo='Nulo'
df_weather2=df_weather1.replace(to_replace=str_Nulo, value=' ', regex=True) 
df_weather2.head()

#Las siguientes lineas son para pasar los datos a numéricos
cols_list=["Precip","Evap","Tmax","Tmin"] #Diccionario para loop for
for cols in cols_list:
  df_weather2[cols]=pd.to_numeric(df_weather2[cols], errors='coerce') 

#df_weather2.info() 

#Las siguientes lienas sirven para un conteo de datos faltantes
#df_weather2.isnull().sum() 

#df_weather2.head()
#df_weather2.tail()

#df_weather2.describe() #Esta línea sirve para el análisis estadístico

#Las siguientes lineas sirven para hacer que Python reconozca el formato de fecha
df_weather3=df_weather2.copy() 
#df_weather3['Fecha'].head() 

df_weather3['Fecha']=pd.to_datetime(df_weather3['Fecha'], dayfirst=True).copy() 
#df_weather3['Fecha'].head()
#df_weather3.dtypes 

df_weather3['Año']=df_weather3['Fecha'].dt.year 
df_weather3['Mes']=df_weather3['Fecha'].dt.month 

#df_weather3.head()
#df_weather3.tail()

df_weather3.info() 

df_weather4=df_weather3.copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17602 entries, 0 to 17601
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fecha   17602 non-null  datetime64[ns]
#  1   Precip  17568 non-null  float64
#  2   Evap    9008 non-null   float64
#  3   Tmax    16608 non-null  float64
#  4   Tmin    16648 non-null  float64
#  5   Año     17602 non-null  int64
#  6   Mes     17602 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(2)
# memory usage: 962.7 KB

# %% [markdown]
# ---
#
#
# **Actividad 4.2**

# %%
# Este código tiene por propósito el crear Histogramas de las variables de Precipitación, Evaporación, 
# Temperaturas Máxima y Mínima de el conjunto de datos que se están analizando. En este caso, la
# climatología de Puerto Peñasco, Sonora.

#plt.hist(df_weather4.Precip, bins=20) 
#plt.xlabel('Precipitación (mm)') 
#plt.ylabel('Frecuencia absoluta') 
#plt.title('Distribucion de precipitación en Puerto Peñasco')
#plt.grid()
#plt.show()

#Cambiando a escala logaritmica.

#plt.hist(df_weather4.Precip, bins=30)
#plt.yscale('log') 
#plt.xlabel('Precipitación (mm)')
#plt.ylabel('log(Frecuencia absoluta)')
#plt.title('Distribucion de precipitación en Puerto Peñasco')
#plt.grid()
#plt.show()

#Notación de librería 'Seaborn':

# Ejemplo 1
#sns.set_style('whitegrid'), plt.xlabel('Precipitación (mm)'), plt.ylabel('Frecuencia Absoluta'), plt.title('Distribución de Precipitación en Puerto Peñasco'),sns.histplot(data=df_weather4, x='Precip',bins=20);
# Ejemplo 2: Escala logarítmica
#sns.set_style('whitegrid'), plt.xlabel('Precipitacion (mm)'), plt.ylabel('Frecuencia Absoluta'), plt.title('Distribución de Precipitación en Puerto Peñasco'),sns.histplot(data=df_weather4, x='Precip',bins=20,log_scale=(False,True));


# Graficando todas las columnas del data frame

# Precipitación
sns.set_style("dark")

MedianaP4=df_weather4.Precip.median()
MediaP4=df_weather4.Precip.mean()

sns.histplot(df_weather4['Precip'],kde=False,color='orange', bins=30,log_scale=(False,True))


plt.axvline(x=MedianaP4,color='b',label='Mediana')
plt.axvline(x=MediaP4,color='g',label='Media')

plt.title('Distribución de precipitación en Puerto Peñasco')
plt.xlabel('log(Precipitacion (mm))')
plt.ylabel('Frecuencia Absoluta')
plt.grid()
plt.show()

# Evaporación
sns.set_style("dark")

MedianaE4=df_weather4.Evap.median()
MediaE4=df_weather4.Evap.mean()

sns.histplot(df_weather4['Evap'],kde=False,color='purple', bins=30,log_scale=(False,True))

plt.axvline(x=MedianaE4,color='red',label='Mediana')
plt.axvline(x=MediaE4,color='orange',label='Media')

plt.title('Distribución de evaporación en la Puerto Peñasco')

plt.xlabel('log(Evaporación (mm))')
plt.ylabel('Frecuencia Absoluta')
plt.grid()
plt.show()

# Temperatura máxima
sns.set_style("dark")

MedianaTmax4=df_weather4.Tmax.median()
MediaTmax4=df_weather4.Tmax.mean()

sns.histplot(df_weather4['Tmax'],kde=False,color='red', bins=30,log_scale=(False,True))

plt.axvline(x=MedianaTmax4,color='blue',label='Mediana')
plt.axvline(x=MediaTmax4,color='green',label='Media')


plt.title('Distribución de temperatura máxima en Puerto Peñasco')

plt.xlabel('log(Tmax (°C))')
plt.ylabel('Frecuencia Absoluta')
plt.grid()
plt.show()

# Temperatura mínima
sns.set_style("dark")

MedianaTmin4=df_weather4.Tmin.median()
MediaTmin4=df_weather4.Tmin.mean()

sns.histplot(df_weather4['Tmin'],kde=False,color='blue', bins=30,log_scale=(False,True))

plt.axvline(x=MedianaTmin4,color='black',label='Mediana')
plt.axvline(x=MediaTmin4,color='red',label='Media')

plt.title('Distribución de temperatura mínima en Puerto Peñasco')

plt.xlabel('log(Tmin (°C))')
plt.ylabel('Frecuencia Absoluta')
plt.grid()
plt.show()

#  La siguiente parte del código sirve para generar gráficas de distribución
# acumulada y normalizadas

# Precipitación
sns.kdeplot(df_weather4['Precip'],fill=True,log_scale=(False,True))

plt.axvline(x=MedianaP4,color='b',label='Mediana')
plt.axvline(x=MediaP4,color='g',label='Media')

plt.xlabel('Precipitación (mm)')
plt.ylabel('Frecuencia normalizada')
plt.title('Distribución normal de la Precipitación en Puerto Peñasco')
plt.grid()
plt.show()

# Evaporación
sns.kdeplot(df_weather4['Evap'],fill=True)

plt.axvline(x=MedianaE4,color='red',label='Mediana')
plt.axvline(x=MediaE4,color='orange',label='Media')
plt.xlabel('Evaporación (mm)')
plt.ylabel('Frecuencia normalizada')
plt.title('Distribución normal de la Evaporación en Puerto Peñasco')
plt.grid()
plt.show()

# Temperatura máxima
sns.kdeplot(df_weather4['Tmax'],fill=True)

plt.axvline(x=MedianaTmax4,color='blue',label='Mediana')
plt.axvline(x=MediaTmax4,color='green',label='Media')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Frecuencia normalizada')
plt.title('Distribución de la Temperatura Máxima en Puerto Peñasco')
plt.grid()
plt.show()

# Temperatura mínima
sns.kdeplot(df_weather4['Tmin'],fill=True)

plt.axvline(x=MedianaTmin4,color='black',label='Mediana')
plt.axvline(x=MediaTmin4,color='red',label='Media')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Frecuencia normalizada')
plt.title('Distribución de la Temperatura Mínima en Puerto Peñasco')
plt.grid()
plt.show()

# Graficandolas juntas

sns.set_style("dark")

sns.histplot(data=df_weather4, x='Precip', bins=20, stat='density');
sns.kdeplot(df_weather4.Precip, fill=True,log_scale=(False,True));

plt.axvline(x=MedianaP4,color='b',label='Mediana')
plt.axvline(x=MediaP4,color='g',label='Media')

plt.xlabel('Precipitación (mm)')
plt.ylabel('Frecuencia normalizada')
plt.title('Distribución normalizada de la Precipitación en Puerto Peñasco')

plt.show()

# Evaporación
sns.set_style("dark")

sns.histplot(data=df_weather4, x='Evap', bins=20, stat='density');
sns.kdeplot(df_weather4.Evap, fill=True);

plt.axvline(x=MedianaE4,color='red',label='Mediana')
plt.axvline(x=MediaE4,color='orange',label='Media')
plt.xlabel('Evaporación (mm)')
plt.ylabel('Frecuencia normalizada')
plt.title('Distribución normal de la Evaporación en Puerto Peñasco')
plt.grid()
plt.show()

# Temperatura máxima
sns.set_style("dark")

sns.histplot(data=df_weather4, x='Tmax', bins=20, stat='density');
sns.kdeplot(df_weather4.Tmax, fill=True);

plt.axvline(x=MedianaTmax4,color='blue',label='Mediana')
plt.axvline(x=MediaTmax4,color='green',label='Media')

plt.title('Distribución de temperatura máxima en Puerto Peñasco')
#plt.yscale('log')
plt.xlabel('Tmax (°C)')
plt.ylabel('Frecuencia Absoluta')
plt.grid()
plt.show()

# Temperatura mínima
sns.set_style("dark")

sns.histplot(data=df_weather4, x='Tmin', bins=20, stat='density');
sns.kdeplot(df_weather4.Tmin, fill=True);

plt.axvline(x=MedianaTmin4,color='blue',label='Mediana')
plt.axvline(x=MediaTmin4,color='green',label='Media')

plt.title('Distribución de temperatura mínima en Puerto Peñasco')
#plt.yscale('log')
plt.xlabel('Tmin (°C)')
plt.ylabel('Frecuencia Absoluta')
plt.grid()
plt.show()

# %% [markdown]
# ---
#
# **Actividad 4.3**

# %%
# Este código sirve para crear las gráficas de cajas (Boxplot) para la 
# Evaporación, Temperaturas Máxima y Mínima

# Evaporación
sns.set_style('dark')
sns.boxplot(x=df_weather4.Evap,data=df_weather4,orient='h').set(xlabel='Evaporacion (mm)',title='Distribución de la Evaporación en Puerto Peñasco');
plt.show()
# Temperatura máxima
sns.set_style('dark')
sns.boxplot(x=df_weather4.Tmax,data=df_weather4,orient='h').set(xlabel='Temperatura Máxima (°C)',title='Distribución de la Temperatura Máxima en Puerto Peñasco');
plt.show()
# Temperatura mínima
sns.set_style('dark')
sns.boxplot(x=df_weather4.Tmin,data=df_weather4,orient='h').set(xlabel='Temperatura Mínima (°C)',title='Distribución de la Temperatura Mínima en Puerto Peñasco');
plt.show()

# %% [markdown]
# ---
#
# **Actividad 4.4**

# %%
# Este código sirve para producir las gráficas de barras para la Precipitación
 # agrupado por Años y después por meses

# Conjunto de datos de 30 años
df_20=df_weather4[(df_weather4['Año']>=1952)&(df_weather4['Año']<1972)]
df_40=df_weather4[(df_weather4['Año']>=1972)&(df_weather4['Año']<1999)] # Hay 7 años en los que hay un hueco de datos, por lo que se despreciaron
df_60=df_weather4[(df_weather4['Año']>=1999)&(df_weather4['Año']<2015)] # Los datos solo alcanzaron para 16 añños aquí

# Precipitación
# De 1952 a 1972

sns.set_style('dark')
plt.figure(figsize=(16,8))

PP20=sns.barplot(x='Año', y='Precip', data=df_20);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Precipitación (mm)')
plt.title('Precipitación Promedio y barras de error para Puerto Peñasco, 1952-1972', fontsize=18)

plt.show()

# de 1972 a 1999
sns.set_style('dark')
plt.figure(figsize=(20,12))

PS40=sns.barplot(x='Año', y='Precip', data=df_40);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Precipitación (mm)')
plt.title('Precipitación Promedio y barras de error para Puerto Peñasco, 1972-1999', fontsize=18)

plt.show()

# De 1999 a 2015
sns.set_style('dark')
plt.figure(figsize=(20,12))

PT60=sns.barplot(x='Año', y='Precip', data=df_60);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Precipitación (mm)')
plt.title('Precipitación Promedio y barras de error para Puerto Peñasco, 1999-2015', fontsize=18)

plt.show()


# Evaporación
# De 1952 a 1972

sns.set_style('dark')
plt.figure(figsize=(16,8))

EV20=sns.barplot(x='Año', y='Evap', data=df_20);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Evaporación (mm)')
plt.title('Evaporación Promedio y barras de error para Puerto Peñasco, 1952-1972', fontsize=18)

plt.show()

# De 1972 a 1999
sns.set_style('dark')
plt.figure(figsize=(20,12))

EP40=sns.barplot(x='Año', y='Evap', data=df_40);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Evaporación (mm)')
plt.title('Evaporación Promedio y barras de error para Puerto Peñasco, 1972-1999', fontsize=18)

plt.show()

# De 1999 a 2015
sns.set_style('dark')
plt.figure(figsize=(20,12))

ET60=sns.barplot(x='Año', y='Evap', data=df_60);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Evaporación (mm)')
plt.title('Evaporación Promedio y barras de error para Puerto Peñasco, 1999-2015', fontsize=18)

plt.show()

# Temperatura máxima
# De 1952 a 1972

sns.set_style('dark')
plt.figure(figsize=(16,8))

TmaxP20=sns.barplot(x='Año', y='Tmax', data=df_20);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Temperatura Máxima (°C)')
plt.title('Temperatura Máxima promedio y barras de error para Puerto Peñasco, 1952-1972', fontsize=18)

plt.show()

# de 1972 a 1999
sns.set_style('dark')
plt.figure(figsize=(20,12))

TmaxS40=sns.barplot(x='Año', y='Tmax', data=df_40);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Temperatura Máxima (C)')
plt.title('Temperatura Máxima Promedio y barras de error para Puerto Peñasco, 1972-1999', fontsize=18)

plt.show()

# De 1999 a 2015
sns.set_style('dark')
plt.figure(figsize=(20,12))

TmaxT60=sns.barplot(x='Año', y='Tmax', data=df_60);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Temperatura Maxima (°C)')
plt.title('Temperatura Máxima Promedio y barras de error para Puerto Peñasco, 1999-2015', fontsize=18)

plt.show()

#Temperatura mínima
# De 1952 a 1972

sns.set_style('dark')
plt.figure(figsize=(16,8))

TminP20=sns.barplot(x='Año', y='Tmin', data=df_20);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Temperatura Mínima (°C)')
plt.title('Temperatura Mínima promedio y barras de error para Puerto Peñasco, 1952-1972', fontsize=18)

plt.show()

# De 1972 a 1999
sns.set_style('dark')
plt.figure(figsize=(20,12))

TminS40=sns.barplot(x='Año', y='Tmin', data=df_40);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Temperatura Mínima (°C)')
plt.title('Temperatura Minima Promedio y barras de error para Puerto Peñasco, 1972-1999', fontsize=18)

plt.show()

# De 1999 a 2015
sns.set_style('dark')
plt.figure(figsize=(20,12))

TminT60=sns.barplot(x='Año', y='Tmin', data=df_60);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Temperatura Mínima (°C)')
plt.title('Temperatura Mínima Promedio y barras de error para Puerto Peñasco, 1999-2015', fontsize=18)

plt.show()




# Agrupación por meses

# De 1952 a 1972

sns.set_style('dark')
plt.figure(figsize=(16,8))

PPM20=sns.barplot(x='Mes', y='Precip', data=df_20);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Meses')
plt.ylabel('Precipitación (mm)')
plt.title('Precipitación Promedio y barras de error para Puerto Peñasco, en meses, 1952-1972', fontsize=18)

plt.show()

# De 1972 a 1999
sns.set_style('dark')
plt.figure(figsize=(20,12))

PSM40=sns.barplot(x='Mes', y='Precip', data=df_40);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Meses')
plt.ylabel('Precipitación (mm)')
plt.title('Precipitación Promedio y barras de error para Puerto Peñasco, en meses, 1972-1999', fontsize=18)

plt.show()

# De 1999 a 2015
sns.set_style('dark')
plt.figure(figsize=(20,12))

PTM60=sns.barplot(x='Mes', y='Precip', data=df_60);
#Rotamos 45º los Años en el eje x para mejor lectura
#f.set_xticklabels(f.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Meses')
plt.ylabel('Precipitación (mm)')
plt.title('Precipitación Promedio y barras de error para Puerto Peñasco, en meses, 1999-2015', fontsize=18)

plt.show()

# %% [markdown]
# ---
#
# **Actividad 4.5**

# %%
# Este código sirve para crear una colección de los últimos 30 años de datos, 
# utilizando condiciones de filtrado por un rango de años y para crear las 
# gráficas de línea de la Precipitación, Temperaturas Máxima y Mínima como 
# funciones del tiempo (Últimos 30 Años).

# Precipitación 
sns.set_style('dark')
plt.figure(figsize=(16,8))

PPL60=sns.lineplot(x='Año', y='Precip', data=df_60);

# Rotamos 45º los Años en el eje x para mejor lectura
#g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right');

plt.xlabel('Años')
plt.ylabel('Precipitación (mm)')
plt.title('Precipitación Promedio y rango de error para Puerto Peñasco, 1999-2015', fontsize=18)

plt.show()

# Temperatura

sns.set_style('dark')
plt.figure(figsize=(16,8))

sns.lineplot(x='Año', y='Tmax', data=df_60, color='r');
sns.lineplot(x='Año', y='Tmin', data=df_60, color='g');

plt.xlabel('Años')
plt.ylabel('Temperaturas (°C)')
plt.title('Temperaturas Tmax y Tmin para Puerto Peñasco, 1999-2015', fontsize=18)

plt.show()

# %% [markdown]
# ---
#
# **Actividad 4.6**

# %%
# Este código sirve para, con el conjunto de 30 años de datos, producir diagramas
# de cajas (Función: sns.boxplot()) para observar la variabilidad de las 
# Temperaturas (Max y Tmin) y la Evaporación agrupados por Mes.

# Temperatura
sns.set_style('dark')
plt.figure(figsize=(16,8))

# Promedio de temperaturas
Tmax_prom = df_weather4.Tmax.mean()
Tmin_prom = df_weather4.Tmin.mean()

# Gráfica de cajas de temperatura máxima
TmaxBox60=sns.boxplot(x='Mes', y='Tmax', data=df_60);
# Líneas
plt.axhline(Tmax_prom, color = 'r', linestyle='--', linewidth=2);
plt.axhline(Tmin_prom, color = 'g', linestyle='--', linewidth=2);

plt.xlabel('Meses')
plt.ylabel('Temperatura (°C)')
plt.title('Variabilidad de la Temperatura Máxima y Mínima para Puerto Peñasco, 1999-2015', fontsize=18)

plt.show()

sns.set_style('dark')
plt.figure(figsize=(16,8))

# Gráfica de cajas de temperatura mínima
TminBox60=sns.boxplot(x='Mes', y='Tmin', data=df_60);
# Líneas
plt.axhline(Tmax_prom, color = 'r', linestyle='--', linewidth=2);
plt.axhline(Tmin_prom, color = 'g', linestyle='--', linewidth=2);

plt.xlabel('Meses')
plt.ylabel('Temperatura (°C)')
plt.title('Variabilidad de la Temperatura Mínima para Puerto peñasco, 1999-2015', fontsize=18)

plt.show()

# Imprimir información de Temperaturas
print('prom(Tmax) = ', Tmax_prom)
print('prom(Tmin) = ', Tmin_prom)
print('Dif Tmax_prom-Tmin_prom = ', (Tmax_prom - Tmin_prom))
# Out:
# prom(Tmax) =  28.88501324662853
# prom(Tmin) =  15.586893320518799
# Dif Tmax_prom-Tmin_prom =  13.298119926109733
