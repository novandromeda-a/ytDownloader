# %% [markdown]
# ![logo.png](data:image/png;base64,...)
#
#
#
# # **Actividad 9**
#
# *Teoría de Estabilidad de las Soluciones de las Ecuaciones Diferenciales Ordinarias*
#
# Iveth Rocio Navarro Lopez
#
#
#
# ---

# %%
import numpy as np
import scipy.linalg as la
from numpy.linalg import matrix_power as mpow
import matplotlib.pyplot as plt
import pylab as pl
import pandas as pd
from scipy import integrate, linalg
import pylab as plt
from matplotlib import cm

# %% [markdown]
# ---
#
# **Actividad 9.1**

# %%
#Una vez que visualizamos la operación matricial, sabemos que los valores 
# 1 y -1 son los que caen en el caso C, donde podemos ubicar a "a" como 0,
#-b como 1 y "b" como -1. Así, procedemos a calcular los eigenvalores de la matriz:

c=np.array([[0,1],[-1,0]])
print('La matriz es ')
print(c) 
print()

eival_1, eivec_1=la.eig(c)

print('Los eigenvectores')
print(eivec_1)
print()

print('Los eigenvalores')
print(eival_1)

print("Para obtener la componente de resultados x:")
v1_1=eivec_1[:,0]
print(v1_1)
v2_1=eivec_1[:,1]
print(v2_1)

t=np.linspace(-10,15,200)
f1=plt.figure();
plt.figure(figsize=(10, 5)); 
for c1 in [0,1,2,3,4]:

  for s in [-1,1]:
    x=s*c1*np.sin(t)-s*c1*np.cos(t)
    y=s*c1*np.sin(t)+s*c1*np.cos(t)
    plt.plot(x,y)

plt.grid();
plt.ylim(-20, 50)
plt.xlim(-6,6)
plt.legend(loc='best');
plt.xlabel('x(t)');
plt.ylabel('y(t)');
plt.title('Soluciones x(t), y(t)');
plt.show();
# Out:
# No handles with labels found to put in legend.
# La matriz es
# [[ 0  1]
#  [-1  0]]
#
# Los eigenvectores
# [[0.70710678+0.j         0.70710678-0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j]]
#
# Los eigenvalores
# [0.+1.j 0.-1.j]
# Para obtener la componente de resultados x:
# [0.70710678+0.j         0.        +0.70710678j]
# [0.70710678-0.j         0.        -0.70710678j]

# %% [markdown]
# ---
# **Actividad 9.2**

# %%
B=np.array([[1,0],[0,1]])
eival2, eivec2=la.eig(B)

print("La matriz es ")
print(B) 
print()

print('Los eigenvectores')
print(eivec2)
print()

print('Los eigenvalores')
print(eival2)

#------------------------------------------------

TraceB=np.trace(B)
print('La traza es')
print(TraceB)
print()
DetB=la.det(B)
print('El determinante es')
print(DetB)
print()
print('Delta es =')
print((TraceB)**2-4*(DetB))
print()

#---------------------------------------------
t=np.linspace(0,5,200)
f1=plt.figure();
plt.figure(figsize=(10, 5)); 
for c1 in [1,2,3,4]:
  for c2 in [1,2,3,4]:
    x=c1*np.exp(t)
    y=c2*np.exp(t)
    plt.plot(t,x,'r-');
    plt.plot(t,y,'b-', alpha=0.5);
plt.grid();
plt.ylim(0, 60)
plt.xlim(-5,7)
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();

#--------------------------------------------

t=np.linspace(0,5,200)
f1=plt.figure();
plt.figure(figsize=(10, 5)); 
for c1 in [1,2,3,4]:
  for c2 in [1,2,3,4]:
    x=c1*np.exp(t)
    y=c2*np.exp(t)
    label='c1=',c1,'c2=',c2
    plt.plot(x,y,label=label);
    
plt.plot(np.exp(t),np.exp(t),'violet',ls='--');
plt.grid();
plt.ylim(0, 60)
plt.xlim(-6,12)
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();
# Out:
# No handles with labels found to put in legend.
# La matriz es
# [[1 0]
#  [0 1]]
#
# Los eigenvectores
# [[1. 0.]
#  [0. 1.]]
#
# Los eigenvalores
# [1.+0.j 1.+0.j]
# La traza es
# 2
#
# El determinante es
# 1.0
#
# Delta es =
# 0.0

# %% [markdown]
# ---
#
# **Actividad 9.3**

# %%
t=np.linspace(0,5,500)
f1=plt.figure();
plt.figure(figsize=(10, 5)); 

for b in [1,2,3,4,5,6]:
  for c1 in [1,2,3]:
    for c2 in[3,4,5,6]:
      x=[]
      y=[]
      for i in t:
        A3=np.array([[0,1],[-1*b^2,0]])
        eigval_3, eigvec_3 = la.eig(A3)
        B11= (eigvec_3[:,0].real).reshape(2,1)
        #print(B11)
        B21=(eigvec_3[:,1].real).reshape(2,1)
        #print(B21)
        B12=(eigvec_3[:,0].imag).reshape(2,1)
        #print(B12)
        B22=(eigvec_3[:,1].imag).reshape(2,1)
        #print(B22)
  
        a=eigval_3.real
        beta1=abs(eigval_3[0].imag)
        #print(a)
        X=(c1*(B11*np.cos(abs(eigval_3[0].imag)*i)-B12*np.sin(abs(eigval_3[0].imag)*i))+c2*(B21*np.cos(abs(eigval_3[1].imag)*i)+B22*np.sin(abs(eigval_3[1].imag)*i)))*np.exp(a*i)
        x.extend(X[0])
        y.extend(X[1])
      plt.plot(x,y)
plt.grid();

plt.legend(loc='best');
plt.xlabel('x');
plt.ylabel('y');

plt.show();
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ---
#
# **Actividad 9.4**

# %%
D=np.array([[-2,0,0],[0,0,2],[0,-2,0]])
print('La matríz es')
print(D)
print()
TraceD=np.trace(D)
print('La traza es')
print(TraceD)
print()
DetD=la.det(D)
print('El determinante es')
print(DetD)
print()
print('Delta es =')
print((TraceD)**2-4*(DetD))
print()
eival4, eivec4=la.eig(D)
print('Los eigenvalores son')
print(eival4)
print()
print('Los eigenvectores son')
print(eivec4)

from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
  
fig = plt.figure()
  
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
t=np.linspace(0,50,300)
# defining all 3 axes
for c1 in [1,4]:
  for c2 in [1,4]:
    for c3 in [1,3]:

      z = c1*np.sin(2*t)-c2*np.cos(2*t)
      x = c3*np.exp(-2*t)
      y =c2*np.sin(2*t)+c1*np.cos(2*t)
      ax.plot3D(x, y, z)
# plotting
#ax.plot3D(x, y, z, 'green')
ax.set_title('Solución en espacio fase')
plt.show()

#---------------Para visualizar una solución en particular------------------


# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
  
fig = plt.figure()
  
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
t=np.linspace(0,50,300)
# defining all 3 axes
for c1 in [1,2,3,4]:
  for c2 in [1,2,3,4]:
    for c3 in [1,2,3,4]:

      z = c1*np.sin(2*t)-c2*np.cos(2*t)
      x = c3*np.exp(-2*t)
      y =c2*np.sin(2*t)+c1*np.cos(2*t)
      
      
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('Solución en espacio fase (singular)')
plt.show()
# Out:
# La matríz es
# [[-2  0  0]
#  [ 0  0  2]
#  [ 0 -2  0]]
#
# La traza es
# -2
#
# El determinante es
# -8.0
#
# Delta es =
# 36.0
#
# Los eigenvalores son
# [ 0.+2.j  0.-2.j -2.+0.j]
#
# Los eigenvectores son
# [[ 0.        +0.j          0.        -0.j          1.        +0.j        ]
#  [-0.70710678+0.j         -0.70710678-0.j          0.        +0.j        ]
#  [ 0.        -0.70710678j  0.        +0.70710678j  0.        +0.j        ]]

# %% [markdown]
# ---
#
# **Actividad 9.5**

# %%
A5=np.array([[-1,0,1],[0,3,0],[-1,0,-1]])
print('La matríz en cuestión A es ')
print(A5)
print()

eival5, eivec5=la.eig(A5)
print('Los eigenvalores son')
print(eival5)
print()
print('Los eigenvectores son')
print(eivec5)


# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
  
fig = plt.figure()
  
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
t=np.linspace(0,50,300)
# defining all 3 axes
for c1 in [1,4]:
  for c2 in [1,4]:
    for c3 in [1,3]:

      x= (c1*np.sin(t)-c2*np.cos(t))*np.exp(-t)
      y = (c1*np.cos(t)+c2*np.sin(t))*np.exp(-t)
      z =c3*np.exp(3*t)
      ax.plot3D(x, y, z)
# plotting
#ax.plot3D(x, y, z, 'green')
ax.set_title('Solución en espacio fase')
plt.xlim(-5,5)
plt.ylim(-5,5)

plt.show()
# Out:
# La matríz en cuestión A es
# [[-1  0  1]
#  [ 0  3  0]
#  [-1  0 -1]]
#
# Los eigenvalores son
# [-1.+1.j -1.-1.j  3.+0.j]
#
# Los eigenvectores son
# [[0.70710678+0.j         0.70710678-0.j         0.        +0.j        ]
#  [0.        +0.j         0.        -0.j         1.        +0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j 0.        +0.j        ]]

# %% [markdown]
# ---
#
# **Actividad 9.6**

# %%
A6=np.array([[-1,0],[1,2]])

print('La matríz en cuestión A es ')
print(A6)
print()

eival6, eivec6=la.eig(A6)
print('Los eigenvalores son')
print(eival6)
print()
print('Los vectores correspondientes son')
print(eivec6)

import numpy as np
from scipy import integrate, linalg
import pylab as plt

def dX_dt(X, t=0):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([ -1*X[0] ,
                  X[0]+2*X[1]])
    
X_f0 = np.array([     0. ,  0.])

print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')

all(dX_dt(X_f0) == np.zeros(2) )

lambda1 = eival6[0]
lambda2 = eival6[1]
print('Eigenvalores')
print('lambda1= ', lambda1)
print('lambda2= ', lambda2)
print(' ')
print('Eigenvectores')
v1 = eivec6[:,0]
v2 = eivec6[:,1]
print('v1=',v1)
print('v2=',v2)


t = np.linspace(1, 5,  500)              
X0 = np.array([0, 3])                     
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
x,y=X.T
plt.plot(x, y, 'violet')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(0, 10)
plt.xlim(-1, 2)
plt.title('Solución X(t) en el plano fase')
plt.show()
# Out:
# La matríz en cuestión A es
# [[-1  0]
#  [ 1  2]]
#
# Los eigenvalores son
# [ 2.+0.j -1.+0.j]
#
# Los vectores correspondientes son
# [[ 0.          0.9486833 ]
#  [ 1.         -0.31622777]]
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0.]
#
# Eigenvalores
# lambda1=  (2+0j)
# lambda2=  (-1+0j)
#
# Eigenvectores
# v1= [0. 1.]
# v2= [ 0.9486833  -0.31622777]

# %% [markdown]
# ---
#
# **Actividad 9.7**

# %%
A7=np.array([[2,1],[1,1]])

print('La matríz en cuestión A es ')
print(A7)
print()

eival7, eivec7=la.eig(A7)
print('Los eigenvalores son')
print(eival7)
print()
print('Los vectores correspondientes son')
print(eivec7)

TraceA=np.trace(A7)
print('La traza es')
print(TraceA)
print()
DetA=la.det(A7)
print('El determinante es')
print(DetA)
print()
print('Delta es =')
print((TraceA)**2-4*(DetA))
print()

def dX_dt(X, t=1):
    """ El lado derecho del sistema de ecuaciones """
    return np.array([ 2*X[0] + X[1] ,
                  X[0]+X[1]])
    
X_f0=np.array([0.0,  0.0  ])

all(dX_dt(X_f0) == np.zeros(2) )


t = np.linspace(1, 5,  500)              
X0 = np.array([1, 1])                    
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
x,y=X.T
plt.plot(x, y, 'violet')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(0, 10)
plt.xlim(0, 10)
plt.title('Solución X(t) en el plano fase')
plt.show()
# Out:
# La matríz en cuestión A es
# [[2 1]
#  [1 1]]
#
# Los eigenvalores son
# [2.61803399+0.j 0.38196601+0.j]
#
# Los vectores correspondientes son
# [[ 0.85065081 -0.52573111]
#  [ 0.52573111  0.85065081]]
# La traza es
# 3
#
# El determinante es
# 1.0
#
# Delta es =
# 5.0

# %% [markdown]
# ---
# **Actividad 9.8**

# %%
A8=np.array([[0,3],[1,-2]])

print('La matríz en cuestión A es ')
print(A8)
print()

eival8, eivec8=la.eig(A8)
print('Los eigenvalores son')
print(eival8)
print()
print('Los vectores correspondientes son')
print(eivec8)


TraceA=np.trace(A8)
print('La traza es')
print(TraceA)
print()
DetA=la.det(A8)
print('El determinante es')
print(DetA)
print()
print('Delta es =')
print((TraceA)**2-4*(DetA))
print()

def dX_dt(X,t=0):
  return np.array([0*X[0]+3*X[1] , X[0]-2*X[1]])

X_f0=np.array([0.0   , 0.0   ])
print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
all(dX_dt(X_f0) == np.zeros(2) )


t = np.linspace(1, 5,  500)            
X0 = np.array([0, 3])                   
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
x, y = X.T
plt.plot(x, y, 'violet')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(0, 10)
plt.xlim(0, 10)
plt.title('Solución X(t) en el plano fase')
plt.show()
# Out:
# La matríz en cuestión A es
# [[ 0  3]
#  [ 1 -2]]
#
# Los eigenvalores son
# [ 1.+0.j -3.+0.j]
#
# Los vectores correspondientes son
# [[ 0.9486833  -0.70710678]
#  [ 0.31622777  0.70710678]]
# La traza es
# -2
#
# El determinante es
# -3.0
#
# Delta es =
# 16.0
#
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0.]

# %% [markdown]
# ---
#
# **Actividad 9.9**

# %%
A9=np.array([[2,0,0],[0,-1,0],[0,2,-3]])
print('La matríz A en cuestión es ')
print(A9)
print('')
eival9, eivec9=linalg.eig(A9)
lambda1_9=eival9[0]
lambda2_9=eival9[1]
lambda3_9=eival9[2]
print('Los eigenvalores son ')
print('lambda1= ',lambda1_9)
print('')

print('lambda2= ',lambda2_9)
print('')

print('lambda3= ',lambda3_9)
print('')
v1=eivec9[:,0]
v2=eivec9[:,1]
v3=eivec9[:,2]
print('Los eigenvectores son ')
print('v1=',v1)
print('')
print('v2=',v2)
print('')
print('v3=',v3)


def dX_dt(X,t=0):
  return np.array([2*X[0],
                   -1*X[1],
                   2*X[1]-3*X[2]])
X_f0=np.array([0.0  ,  0.0 ,   0.0 ])

print('Los puntos criticos del sistema son ')
print(X_f0)
print()

all(dX_dt(X_f0)==np.zeros(3))


t=np.linspace(0,15,700)
fig = plt.figure()
ax = plt.axes(projection ='3d')


for b in [1,2,3,4,5]:
  X0=np.array([0,-1*b,b])
  X, infodict = integrate.odeint(dX_dt,X0,t,full_output=True)
  infodict['message']
  x ,y ,z = X.T
  ax.plot3D(x, y, z,)



label='Familias de soluciones en el espacio fase (x(t),y(t),z(t))'
ax.set_title(label)
plt.xlim(-7, 7)
plt.ylim(-7, 7)
plt.xlabel('x');
plt.ylabel('y');
plt.show()
# Out:
# La matríz A en cuestión es
# [[ 2  0  0]
#  [ 0 -1  0]
#  [ 0  2 -3]]
#
# Los eigenvalores son
# lambda1=  (2+0j)
#
# lambda2=  (-3+0j)
#
# lambda3=  (-1+0j)
#
# Los eigenvectores son
# v1= [1. 0. 0.]
#
# v2= [0. 0. 1.]
#
# v3= [0.         0.70710678 0.70710678]
# Los puntos criticos del sistema son
# [0. 0. 0.]

# %% [markdown]
# ---
#
# **Actividad 9.10**

# %%
#-------------Parte homogenea---------------------
k2=4
k1=6
b1=0
b2=0
A10=np.array([[0,1,0,0],[-1*(k2+k1),-1*b1,k2,0],[0,0,0,1],[k2,0,-1*k2,-1*b2]])
print('La matrÍz en cuestión es ')
print(A10)
print()
C=np.array([[0],[2],[0],[4]])
def dX_dt(X,t=0):
  return np.array([X[1] , -1*(k2+k1)*X[0] -1*b1*X[1] +k2*X[2]  ,  
                   X[3]  ,   -1*k2*X[2]+k2*X[0]])
  
C_sol=la.solve(A10,-1*C)
print(C_sol)

X_f0=np.array([0.0  , 0.0  , 0.0  , 0.0  ])

X0=np.array([0.0  , 0.0  ,2.0  , 0.0  ])

print('Puntos crÍticos del sistema para los valores dados')
print('X_f0=   ',X_f0)

#all(dX_dt(X_f0)== np.zeros(4) ) and all(dX_dt(X_f1)==np.zeros(4))
all(dX_dt(X_f0) == np.zeros(4) ) #and all(dX_dt(X_f1) == np.zeros(4))

#np.array([X[1] , -1*(k2+k1)*X[0] -1*b1*X[1] +k2*X[2]  ,  
#                   X[3]  ,   -1*k2*X[2]+k2*X[0]])
def d2X_dt2(X,t=0):
  return np.array([ [0  ,         1 ,    0 , 0], 
                   [-1*(k2+k1), -1*b1,   k2,  0 ], 
                   [0,               0,    0,   1],
                  [k2 ,  0  ,  -1*k2,  0   ]])

A_f1=d2X_dt2(X_f0)
print('Jacobiano evaluado en punto crÍtico')
print(A_f1)
lambda1,lambda2,lambda3,lambda4=linalg.eigvals(A_f1)
print('eigenvalores del jacobiano en X')
print(lambda1)
print(lambda2)
print(lambda3)
print(lambda4)

T_f1 = 2*np.pi/abs(lambda1) 
print('Periodo:', T_f1)
#T_f2 = 2*np.pi/abs(lambda3) 
#print('Periodo 2:', T_f1)

t=np.linspace(0,30,1000)

X,infodict=integrate.odeint(dX_dt,X0,t,full_output=True)
infodict['message']

x1, x3, x2, x4 =X.T+C_sol
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x1, 'r-', label='masa 1');
plt.plot(t, x2, 'b-', label='masa 2');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('ubicación');
plt.title('EvoluciÓn de un sistema compuesto');
plt.show();

#------------------------------------------------------------

values  = np.linspace(1, 10, 1) 
# posición de X0 entre X_f0 y X_f1
vcolors = plt.cm.cividis(np.linspace(0.3, 1., len(values))) 

plt.figure(figsize=(12, 8)); 

#-------------------------------------------------------
for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,0], X[:,2], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[0], X0[2]) )
ymax = plt.ylim(ymin=0)[1]                        # get axis limits
xmax = plt.xlim(xmin=0)[1]

for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,1], X[:,3], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[1], X0[3]) )
#-------------------------------------------------------

y2max= plt.ylim(ymin=0)[1]   
x2max= plt.xlim(xmin=0)[1] 
nb_points   = 20

x = np.linspace(0, xmax, nb_points)
y = np.linspace(0, ymax, nb_points)
x2 = np.linspace(0, x2max, nb_points)
y2 = np.linspace(0, y2max, nb_points)

X1 , Y1 = np.meshgrid(x, y)     
X2 , Y2 = np.meshgrid(x2, y2)                   
DX1, DY1, DX2, DY2 = dX_dt([X1, Y1, X2  , Y2]) 

M = (np.hypot(DX1, DY1))                         
M[ M == 0] = 1.                                 
DX1 /= M                                        
DY1 /= M

#-------------------------------------------------------

plt.title('Plano Fase: Trayectorias y campo de direcciones - Punto crítico (0,0)')
Q = plt.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=plt.cm.inferno)
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(loc='best')
plt.grid()
plt.xlim(0, xmax)
plt.ylim(0, ymax)
plt.show()

#------------------------------------------------------------

k2=4
k1=6
b1=0.1
b2=0.2
A10=np.array([[0,1,0,0],[-1*(k2+k1),-1*b1,k2,0],[0,0,0,1],[k2,0,-1*k2,-1*b2]])
print('La matríz en cuestión es ')
print(A10)
print()
C=np.array([[0],[2],[0],[4]])
def dX_dt(X,t=0):
  return np.array([X[1] , -1*(k2+k1)*X[0] -1*b1*X[1] +k2*X[2]  ,  
                   X[3]  ,   -1*k2*X[2]+k2*X[0]])
  
#---------------------------------------------
  C_sol=la.solve(A10,-1*C)
print(C_sol)
#------------------------------------------------
X_f0=np.array([0.0  , 0.0  , 0.0  , 0.0  ])
X0=np.array([0.0  , 0.0  ,2.0  , 0.0  ])

print('Puntos críticos del sistema para los valores dados')
print('X_f0=   ',X_f0)

#all(dX_dt(X_f0)== np.zeros(4) ) and all(dX_dt(X_f1)==np.zeros(4))
all(dX_dt(X_f0) == np.zeros(4) ) #and all(dX_dt(X_f1) == np.zeros(4))

#------------------------------------------------
#np.array([X[1] , -1*(k2+k1)*X[0] -1*b1*X[1] +k2*X[2]  ,  
#                   X[3]  ,   -1*k2*X[2]+k2*X[0]])
def d2X_dt2(X,t=0):
  return np.array([ [0  ,         1 ,    0 , 0], 
                   [-1*(k2+k1), -1*b1,   k2,  0 ], 
                   [0,               0,    0,   1],
                  [k2 ,  0  ,  -1*k2,  0   ]])
#Jacobiano evaluado en el punto crítico
A_f1=d2X_dt2(X_f0)
print('Jacobiano evaluado en punto crítico')
print(A_f1)
lambda1,lambda2,lambda3,lambda4=linalg.eigvals(A_f1)
print('eigenvalores del jacobiano en X')
print(lambda1)
print(lambda2)
print(lambda3)
print(lambda4)

#------------------------------------------------------
T_f1 = 2*np.pi/abs(lambda1) 
print('Periodo:', T_f1)
#T_f2 = 2*np.pi/abs(lambda3) 
#print('Periodo 2:', T_f1)
#------------------------------------------
t=np.linspace(0,30,1000)

X,infodict=integrate.odeint(dX_dt,X0,t,full_output=True)
infodict['message']
#------------------------------------------------
x1, x3, x2, x4 =X.T+C_sol
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x1, 'r-', label='masa 1');
plt.plot(t, x2, 'b-', label='masa 2');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('ubicación');
plt.title('Evolución de un sistema compuesto');
plt.show();
#----------------------------------------
tr=np.linspace(0,500,5000)

X,infodict=integrate.odeint(dX_dt,X0,tr,full_output=True)
infodict['message']
x1, x3, x2, x4 =X.T+C_sol
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(tr, x1, 'r-', label='masa 1');
plt.plot(tr, x2, 'b-', label='masa 2');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('ubicación');
plt.title('Evolución de un sistema compuesto');
plt.show();
#-------------------------------------

values  = np.linspace(1, 10, 1) 

vcolors = plt.cm.cividis(np.linspace(0.3, 1., len(values))) 

plt.figure(figsize=(12, 8)); 

#-------------------------------------------------------

for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
  
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,0], X[:,2], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[0], X0[2]) )
ymax = plt.ylim(ymin=0)[1]                        # get axis limits
xmax = plt.xlim(xmin=0)[1]

for v, col in zip(values, vcolors):
    X0 = v * X_f0                             

    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,1], X[:,3], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[1], X0[3]) )
#-------------------------------------------------------

y2max= plt.ylim(ymin=0)[1]   
x2max= plt.xlim(xmin=0)[1] 
nb_points   = 20

x = np.linspace(0, xmax, nb_points)
y = np.linspace(0, ymax, nb_points)
x2 = np.linspace(0, x2max, nb_points)
y2 = np.linspace(0, y2max, nb_points)

X1 , Y1 = np.meshgrid(x, y)     
X2 , Y2 = np.meshgrid(x2, y2)                    
DX1, DY1, DX2, DY2 = dX_dt([X1, Y1, X2  , Y2]) 


M = (np.hypot(DX1, DY1))                           
M[ M == 0] = 1.                               
DX1 /= M                                       
DY1 /= M

#-------------------------------------------------------

plt.title('Plano Fase: Trayectorias y campo de direcciones - Punto crítico (0,0)')
Q = plt.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=plt.cm.inferno)
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(loc='best')
plt.grid()
plt.xlim(0, xmax)
plt.ylim(0, ymax)
plt.show()
# Out:
# La matrÍz en cuestión es
# [[  0   1   0   0]
#  [-10   0   4   0]
#  [  0   0   0   1]
#  [  4   0  -4   0]]
#
# [[1.]
#  [0.]
#  [2.]
#  [0.]]
# Puntos crÍticos del sistema para los valores dados
# X_f0=    [0. 0. 0. 0.]
# Jacobiano evaluado en punto crÍtico
# [[  0   1   0   0]
#  [-10   0   4   0]
#  [  0   0   0   1]
#  [  4   0  -4   0]]
# eigenvalores del jacobiano en X
# (2.220446049250313e-16+3.464101615137756j)
# (2.220446049250313e-16-3.464101615137756j)
# (-1.3877787807814457e-16+1.414213562373095j)
# (-1.3877787807814457e-16-1.414213562373095j)
# Periodo: 1.813799364234217
# La matríz en cuestión es
# [[  0.    1.    0.    0. ]
#  [-10.   -0.1   4.    0. ]
#  [  0.    0.    0.    1. ]
#  [  4.    0.   -4.   -0.2]]
#
# [[1.]
#  [0.]
#  [2.]
#  [0.]]
# Puntos críticos del sistema para los valores dados
# X_f0=    [0. 0. 0. 0.]
# Jacobiano evaluado en punto crítico
# [[  0.    1.    0.    0. ]
#  [-10.   -0.1   4.    0. ]
#  [  0.    0.    0.    1. ]
#  [  4.    0.   -4.    0. ]]
# eigenvalores del jacobiano en X
# (-0.03999936001028768+3.463593494852212j)
# (-0.03999936001028768-3.463593494852212j)
# (-0.010000639989712207+1.414291364612996j)
# (-0.010000639989712207-1.414291364612996j)
# Periodo: 1.8139444972104801
